# %% [markdown]
# ### Comment analysis of online shopping

# %% [markdown]
# ###### 注：本文档为实验代码，展示代码见crawler_showcase

# %% [markdown]
# ##### 所需库

# %%
import requests
from bs4 import BeautifulSoup as bs
import json
import csv
import re
import pandas as pd
import browser_cookie3

# %% [markdown]
# ##### 小例子，爬取表格并生成csv

# %%
for i in range(1,178):  # 爬取全部页
    tb = pd.read_html('http://s.askci.com/stock/a/?reportTime=2017-12-31&pageNum=%s' % (str(i)))[3] 
    # tb.to_csv(r'1.csv', mode='a', encoding='utf_8_sig', header=1, index=0)

# %%
tb = pd.read_html('http://s.askci.com/stock/a/?reportTime=2017-12-31&pageNum=%s' % (str(1)))[3]

# %% [markdown]
# ##### 爬取淘宝评论

# %%
url = 'https://rate.taobao.com/feedRateList.htm?'
headers = {
    'referer':'https://item.taobao.com/item.htm?spm=a21n57.1.0.0.3c71523cldqQa6&id=741068226941&ns=1&abbucket=10',
    "user-agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    'cookie':"cna=FDnFHUQV/ikCAY1I7e7fOdfn; _m_h5_tk=3b40dcb2d56b170cbb8edd6904874d37_1700005329697; _m_h5_tk_enc=c2e34149b7e98efcfc9fedceeb1db62f; xlly_s=1; cookie2=1c47e03dfc988713b6db6a3449fc7f6c; t=7a1c219cd70887161d3e51a79e52bdcd; _tb_token_=ee66be1145b8e; _samesite_flag_=true; sgcookie=E100S56b65w2exocuO59xIMYkhK1h1LM4EtkAtlaODeDoIYkYhC8kUAQNFp1NDmUP1MZScCGWwOh7DK0jXeAWsvJRYMTEu%2FLl3qjSzGgfxzmPPRuzho9k2DOBXkyBHn8UUeh; unb=2637962049; uc3=lg2=Vq8l%2BKCLz3%2F65A%3D%3D&id2=UU6ie%2BaNBEf%2FCQ%3D%3D&nk2=rrrds%2F5y83rSSQ%3D%3D&vt3=F8dD3CIetmOw4tA%2BIpg%3D; csg=033443df; lgc=%5Cu74E6%5Cu4F26%5Cu4E01%5Cu7684%5Cu96EA; cancelledSubSites=empty; cookie17=UU6ie%2BaNBEf%2FCQ%3D%3D; dnk=%5Cu74E6%5Cu4F26%5Cu4E01%5Cu7684%5Cu96EA; skt=1b86afcd9df09b38; existShop=MTY5OTk5NjM5OA%3D%3D; uc4=nk4=0%40rOD5ZnopMTX9wSXsqPR%2FkPSmQ6B0&id4=0%40U2xvL0Or1xFQEEavrJ4ph4nVa1yy; tracknick=%5Cu74E6%5Cu4F26%5Cu4E01%5Cu7684%5Cu96EA; _cc_=URm48syIZQ%3D%3D; _l_g_=Ug%3D%3D; sg=%E9%9B%AA9b; _nk_=%5Cu74E6%5Cu4F26%5Cu4E01%5Cu7684%5Cu96EA; cookie1=BxJIvnjK%2Fs9rxp0cXZryRKC3fv%2BC788H52JfKgnljBM%3D; _uetsid=caee91b0833011ee9a5bc901ca2ee3eb; _uetvid=c4d10360765311ee9080597f1ae094cc; mt=ci=47_1; uc1=pas=0&cookie14=Uoe9ZLHcWU7yKw%3D%3D&existShop=false&cookie15=UtASsssmOIJ0bQ%3D%3D&cookie21=WqG3DMC9Fb5mPLIQo9kR&cookie16=Vq8l%2BKCLySLZMFWHxqs8fwqnEw%3D%3D; hng=CN%7Czh-CN%7CCNY%7C156; thw=cn; l=fBrFAqqgPbkh0ZJ3BO5aourza77taIdb8sPzaNbMiIEGa6i1wUOYlNCTnN8ekdtjQTfm1eKyMAhYGdUy874U-ETjGO0qOC0eQxv9-bpU-L5..; tfstk=d9Hpf9TbUFYHLNWK0wdMzqWX5q-i9vnEX2ofEz4hNV3t-mG3t0aue43-yyVW8JD-W2mjtWmSEuM8LAchEyYUe0g0eEYDnKmEYJyWmEAwYLzer8yGGlfsYDyzFGbWifiFeb_dKGGHxT7Bm9kEekOl8hJ8dtr7vWURtP68GAX0OriQWTTjeO--nxnM1Z4Yq6t9X_5zOlJ5jbm1.; isg=BB4er-xB9xpNYCMTswT0IdK0b7Rg3-JZyXt5E8imX2F667_FMW67aOXN4-9nU9px"
}

params = {
    'auctionNumId': 741068226941,
    'currentPageNum': 1
    }

page = requests.get(url,params=params, headers=headers).text
page=json.loads(re.sub(r'[\n\r()]', '', page))
page
# Out:
# {'rgv587_flag': 'sm',
#  'url': 'https://rate.taobao.com:443//feedRateList.htm/_____tmd_____/punish?x5secdata=xdd438afa72fe5d1720f9418a05f33e52f2afbc55add7a97581700001459a978159309a137274137abaac2aaa__bx__rate.taobao.com%3A443%2FfeedRateList.htm&x5step=100'}

# %%
# 查看字典类型的所有关键字

page.keys()
# Out:
# dict_keys(['qnaDisabled', 'watershed', 'total', 'totalFuzzy', 'comments', 'currentPageNum', 'maxPage'])

# %%
print(type(page['comments']))
len(page['comments'])
# Out:
# <class 'list'>
# 20

# %%
for item in page['comments']:
    prop = (item['auction']['sku'])
    match = re.search(r'颜色分类:(\S+).*尺码:(\w+)', prop)
    # 如果匹配成功，获取颜色分类和尺码
    if match:
        color = match.group(1)
        size = match.group(2)
        print("颜色分类:", color)
        print("尺码:", size)
    else:
        pass
# Out:
# 颜色分类: 经典灰【笑脸连帽】加绒&nbsp;&nbsp
# 尺码: S
# 颜色分类: 奶灰色【小熊连帽】加绒&nbsp;&nbsp
# 尺码: XL
# 颜色分类: 燕麦灰【笑脸连帽】加绒&nbsp;&nbsp
# 尺码: S
# 颜色分类: 经典黑【笑脸连帽】加绒&nbsp;&nbsp
# 尺码: XL
# 颜色分类: 抹茶绿【背后花花】不加绒&nbsp;&nbsp
# 尺码: L

# %%
for item in page['comments']:
    print(item['content'])
# Out:
# 全新有吊牌有防尘袋灰色连帽S码 我穿不合适出掉！有喜欢的来找我！实物很好看！因为韩代不优惠，所以很合适了！没删这条就是还在！！❤️❤️❤️
# 奶灰色无敌好看
# 很适合很喜欢很舒服大小刚刚好！！
# 评价方未及时做出评价,系统默认好评!
# 评价方未及时做出评价,系统默认好评!
# 评价方未及时做出评价,系统默认好评!
# 评价方未及时做出评价,系统默认好评!
# 评价方未及时做出评价,系统默认好评!
# 评价方未及时做出评价,系统默认好评!
# 评价方未及时做出评价,系统默认好评!
# 此用户没有填写评价。
# 评价方未及时做出评价,系统默认好评!
ZTj1OJlBFUkRDX1NIUFBfWU49TiZNQlJTUF9QRVJEX1RZUEVfQ0Q9JlNTX0NBUkRfWU49TiZHQT0yMjUmTUJSU1BfUEFZTVRfVFlQRV9DRD0mTUJSX05NPU1PVSBTSVlJTkcmTUJSU1BfTUJSX0RJVl9DRD0yMDAxJk1CUl9HUkRfQ0Q9MTAmTUJSU1BfSk9JTl9TSVRFX0NEPSZldD0xNzAwMDUxMTEzMzgz; FSID1=s45zu1s6vgz3x206l6m7; _dd_s=rum=0&expire=1700052027656'
    }

params = {
    'itemId': '1000039995220',
    'siteNo': '6001',
    'page': '1' # list(map(str, range(10, 100))) 高级用法map映射，但在这里无法起到多页作用，用循环
    }

page_json = requests.get(url, params=params, headers=headers).text
page = json.loads(re.sub(r'[\n\r()]', '', page_json)) # 将page中的换行符（\n）、回车符（\r）和括号（()）替换为空字符串，并将经过预处理的JSON字符串转换为相应的Python数据结构（通常是字典或列表），以便在代码中进一步处理
print('page type: ', type(page))
# page.keys() # 查看字典类型page的所有键

# 存储为json形式方便下次读取，不必再次联网请求

with open("kurly_rice_comment.json", "w", encoding="utf-8") as file:
    json.dump(page_json, file)

# 读取json文件

with open("kurly_rice_comment.json", "r", encoding="utf-8") as file:
    stored_data = json.load(file)
    parsed_data = json.loads(re.sub(r'[\n\r()]', '',stored_data))
    print('parsed_data type: ', type(parsed_data))

page == parsed_data # 验证存储和读出内容是否一致

# %%
# 爬取多页数据，存储在pages中，pages的形式为[dict1, dict2, ...]，注意该网站一次只允许爬取少于100页，否则会出现未响应的情况

import time

url = 'https://emart.ssg.com/item/ajaxItemCommentList.ssg?'
headers = {
    'referer':'https://emart.ssg.com/item/itemView.ssg?itemId=1000039995220&siteNo=6001&salestrNo=2498',
    "user-agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    'cookie': '_xm_webid_1_=-646844791; CHECKED=d582684c83b011ee98d0506b8d43158666031770658845912; PCID=17000506014648520748705; FSID=s45zft3x206l6ms6vgz3; where=SE%3DY%26CHNL_ID%3D0000015201%26CK_WHERE%3Ddirect_emart%26et%3D1700050601465; CKWHERE=direct_emart; TS01292a13=010874cb80c595b12c68d88fccac7a4c38ff99d47b31fb2178a821998bee70e84fe462d6a70e7b53c877265ec90fdef28de21d5fc7; SSGDOMAIN=emart_emart; RC_RESOLUTION=1536*864; RC_COLOR=24; _gcl_au=1.1.456748553.1700050603; TS01c8d6a7=010874cb80583b06a064437286382f74bed224e94d12c482f1c263e6b02336cb572084fd1078aa213fc633b468e1ccf2b3e14e5904; _fbp=fb.1.1700050607683.1253639838; emf.272.euuid.v5=e81f8633-m1c2-4598-s124-fa64e3e6f4a2; _ga=GA1.1.265855336.1700050608; TS01d9c9c9=010874cb800099f38daf6f3d4159e0e975d0dce181398c6b34cc2e1edecf5dbbbb141211f7e7648a45ff38af7aa68ad1ad477c9cab; analytics_sp=N; target_sp=N; TS0197eadc=010874cb80e8b084040b54b0176bd52d5daaa698911d7b8c7b8e69c8e825fff96abfef906b0c92186d76ccc680126c26c44e973f2a; FS0=2qpKTRu5iBrkC
217000506014648520748705%22%2C%22c%22%3A1700050816620%2C%22l%22%3A1700050816623%7D; ab.storage.deviceId.113debac-6879-41dd-ad72-aa2b290b8502=%7B%22g%22%3A%22095e1ee4-a478-1229-49d6-b3c98453e6d3%22%2C%22c%22%3A1700050816624%2C%22l%22%3A1700050816624%7D; CLIP_SAVE_DATA=null; CSTALK_POPUP_OPEN=null; cto_bundle=xNnCA195Tnc3d2R3JTJCS3lHZiUyQlRqeFl5JTJCQ2t4UDNhNkhCSnZvRmc3VTVXTkFIaSUyQlVwVHBjbTJiTkw3Z2NvcXJESEl3SmU2USUyQlN1VW1YUDBqRzlSbkdSV1FNUUJRdElBV3ZBc1ZxOU5RQ1RlRGRwMllMUTdVb2h3WFlBakw3bmhXMVMyNzA; TS015a5cbc=010874cb80c8eedc72d5fb7c6a4d7e14017a9401cd676e5409156317ffb2c8da50550e5115aa435d8eaa64b90065e2804a3eb8561d; _ga_E0P8DK53C8=GS1.1.1700050607.1.1.1700051105.22.0.0; JSESSIONID=C41AF3A23973275A3577EAEED90838FC.emart3605; FS1=SERfUExDQ19ZTj1OJlBFUkRDX1NIUFBfWU49TiZNQlJTUF9QRVJEX1RZUEVfQ0Q9JlNTX0NBUkRfWU49TiZHQT0yMjUmTUJSU1BfUEFZTVRfVFlQRV9DRD0mTUJSX05NPU1PVSBTSVlJTkcmTUJSU1BfTUJSX0RJVl9DRD0yMDAxJk1CUl9HUkRfQ0Q9MTAmTUJSU1BfSk9JTl9TSVRFX0NEPSZldD0xNzAwMDUxMTEzMzgz; FSID1=s45zu1s6vgz3x206l6m7; _dd_s=rum=0&expire=1700052027656'
    }

params = {
    'itemId': '1000039995220',
    'siteNo': '6001',
    'page': '1' # list(map(str, range(10, 100))) 高级用法map映射，但在这里无法起到多页作用，用循环
    }

pages = [] # list for storing original page dicts

# %%
page_num = 10 * 99 + 3 * 1089 + 1 # total page number, to be updated

for i in range(page_num, page_num + 99):
    params['page'] = str(i)
    page = requests.get(url, params=params, headers=headers).text
    pages.append(page)
print('Pages list length: ', len(pages))
# Out:
# Pages list length:  1089

# %%
# pages.pop()
len(pages)
# Out:
# 1089

# %%
99 * 10
# Out:
# 990

# %%
# 将列表中的数据以JSON格式写入文件

with open("rice_comment_4th_1089.json", "w", encoding="utf-8") as file:
    json.dump(pages, file, ensure_ascii=False, indent=2)

print("数据已以JSON格式写入文件")
# Out:
# 数据已以JSON格式写入文件

# %% [markdown]
# ###### 读取预存json文件，包括所有上万条评论

# %%
with open("rice_comment_4th_1089.json", "r", encoding="utf-8") as file:
    stored_data = json.load(file)
stored_data == pages
# Out:
# True

# %% [markdown]
# ###### 所有关于速食米饭评论数据挖掘的功能函数集合

# %%
# 1. 收集所有页面的评论，并写入Excel中

def searchComment():

    # set number of pages here
    page_num = 166
    comment_list = []
    for i in range(1, page_num):
        params['page'] = str(i)
        page = requests.get(url, params=params, headers=headers).text
        page = json.loads(re.sub(r'[\n\r()]', '', page))
        for j in range(10):
            comment_list.append(page['pageDto']['resultList'][j]['postngTitleNm'])

    # write into excel
    df = pd.DataFrame({'Comments': comment_list})
    excel_file_path = 'comments.xlsx'
    df.to_excel(excel_file_path, index=False)
    print(f'Comments DataFrame has been written to {excel_file_path}')

    return comment_list


# 2. 文本预处理：tokenization，数据清洗等

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

def tokenizationComment(text):  # 2.1 tokenization: 输入为string类型，输出list类型

    words = word_tokenize(text)
    # 去除停用词和符号
    stop_words = set(stopwords.words('korean'))
    filtered_words = [word for word in words if word.isalnum() and word not in stop_words]

    return filtered_words

def del_repetition(filtered_words): # 2.2 输入list类型，输出list类型，包含了tokenizationComment函数

    comment_list_cleared = []
    for i in range(len(filtered_words)):
        filtered_words_list = tokenizationComment(filtered_words[i])
        comment_list_cleared.append(list(set(filtered_words_list)))

    return comment_list_cleared


# 3. 收集评分

# page['pageDto']['resultList'][0]['recomEvalScr'] # recommend evaluation scores

def recomEvalScr(): # 输入pages，输出评分列表

    evalScr_list = []
    
    return evalScr_list

# %% [markdown]
# ###### 具体执行各功能

# %%
# 1. 收集所有页面的评论，以字符串形式存储在列表中

comment_list = searchComment()
# Out:
# Comments DataFrame has been written to comments.xlsx

# %%
# 2. 文本预处理：tokenization，数据清洗等

comment_list_cleared = del_repetition(comment_list)
comment_list_cleared
# Out:
# [['먹고',
#   '갓',
#   '찰기도는',
#   '저렴한',
#   '지은',
#   '제일',
#   '돌려주면',
#   '한번에',
#   '먹는',
#   '너무',
#   '보관해야',
#   '되어서',
#   '들더라고요',
#   '초기엔',
#   '햇반',
#   '브랜드와',
#   '느끼기엔',
#   '차이',
#   '밥을',
#   '냉동',
#   '전자레인지에',
#   '돌아',
#   '40만원짜리',
#   '현재는',
#   '있',
#   '사놓고',
#   '없어요',
#   '나오고요',
#   '고슬고슬',
#   '제가',
#   '1분',
#   '했지만',
#   '못먹으니까',
#   '2분',
#   '먹기도',
#   '시켜',
#   '돌고',
#   '밥이',
#   '브랜드랑',
#   'ㅎㅎ',
#   '맛이',
#   '지어',
#   '일이',
#   '이게',
#   '막입인',
#   '다',
#   '노브랜드',
#   '밥솥',
#   '찾다가',
#   '햇반에',
#   '남은',
#   '비교해도',
#   '해서',
#   '정도',
#   '저렴하고',
#   '타',
#   '노브랜드만',
#   '직접',
#   '두배로',
#   '맛도',
#   '귀찮고',
#   '30초',
#   '그맛이고',
#   '정착했는데',
#   '또는',
#   '자취생이라'],
#  ['굴렸나', '식품', '모양인가요', '용기에', '이물질', '바닥에', '검은'],
#  ['가성비', '굿', '길어요', '입니다', '밥', '맛', '유통기간', '좋아요'],
#  ['데우지않고',
#   '이걸',
#   '데워야',
#   '이제',
#   '그대로',
#   '알았을까',
#   '있는',
#   '밥들은',
#   '노브랜드밥은',
#   '너무',
#   '그냥',
#   '찰기가',
#   '먹어도',
#   '맛나요',
#   '맛있어요',
# ...

# %%
# 查看当前程序内存占用

import psutil
import os

print(u'当前进程的内存使用：%.4f GB' % (psutil.Process(os.getpid()).memory_info().rss / 1024 / 1024 / 1024) )
# Out:
# 当前进程的内存使用：0.0807 GB
